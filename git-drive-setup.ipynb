# %% [markdown]
# Mount your Google Drive directory onto your Colab session

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Change directories to where you want your repo

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/github
# Out:
# /content/drive/MyDrive/Colab Notebooks/github

# %% [markdown]
# Clone the repository from your GitHub page

# %%
# !git clone https://github.com/edavis8/Colab.git
# Out:
# Cloning into 'Colab'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %% [markdown]
# Add any changes made in Drive/Collab

# %%
# !git add .

# %%
# !git config user.email "edavis4@uvm.edu"
# !git config user.name "Ethan Davis"

# %% [markdown]
# Commit Changes

# %%
# !git commit -am "add drive setup"
# Out:
# [main 2a29e75] add drive setup
#  1 file changed, 1 insertion(+)
#  create mode 100644 git-drive-setup.ipynb

# %% [markdown]
# Push changes to the remote repository

# %%
# !git push -u Colab main
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.79 KiB | 915.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
